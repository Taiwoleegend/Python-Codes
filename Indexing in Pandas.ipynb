# %% [markdown]
# # Indexing

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Abiola Taiwo\Documents\Taiwo Abiola PortfolioProjects\Wikipedia Web Scrapping.csv")

# %%
df
# Out:
#     Rank                  Name                    Industry  \
# 0      1               Walmart                      Retail
# 1      2                Amazon  Retail and cloud computing
# 2      3                 Apple        Electronics industry
# 3      4    UnitedHealth Group                  Healthcare
# 4      5    Berkshire Hathaway                Conglomerate
# ..   ...                   ...                         ...
# 95    96                  TIAA                  Financials
# 96    97                   CHS     Agriculture cooperative
# 97    98  Bristol-Myers Squibb     Pharmaceutical industry
# 98    99  Dow Chemical Company           Chemical industry
# 99   100              Best Buy                      Retail
#
#    Revenue (USD millions) Revenue growth  Employees  \
# 0                 648,125           6.0%  2,100,000
# 1                 574,785          11.9%  1,525,000
# 2                 383,482          -2.8%    161,000
# ...

# %%
df = pd.read_csv(r"C:\Users\Abiola Taiwo\Documents\Taiwo Abiola PortfolioProjects\Wikipedia Web Scrapping.csv", index_col = "Name")

df
# Out:
#                       Rank                    Industry Revenue (USD millions)  \
# Name
# Walmart                  1                      Retail                648,125
# Amazon                   2  Retail and cloud computing                574,785
# Apple                    3        Electronics industry                383,482
# UnitedHealth Group       4                  Healthcare                371,622
# Berkshire Hathaway       5                Conglomerate                364,482
# ...                    ...                         ...                    ...
# TIAA                    96                  Financials                 45,735
# CHS                     97     Agriculture cooperative                 45,590
# Bristol-Myers Squibb    98     Pharmaceutical industry                 45,006
# Dow Chemical Company    99           Chemical industry                 44,622
# Best Buy               100                      Retail                 43,452
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                     Name  Rank                    Industry  \
# 0                Walmart     1                      Retail
# 1                 Amazon     2  Retail and cloud computing
# 2                  Apple     3        Electronics industry
# 3     UnitedHealth Group     4                  Healthcare
# 4     Berkshire Hathaway     5                Conglomerate
# ..                   ...   ...                         ...
# 95                  TIAA    96                  Financials
# 96                   CHS    97     Agriculture cooperative
# 97  Bristol-Myers Squibb    98     Pharmaceutical industry
# 98  Dow Chemical Company    99           Chemical industry
# 99              Best Buy   100                      Retail
#
#    Revenue (USD millions) Revenue growth  Employees  \
# 0                 648,125           6.0%  2,100,000
# 1                 574,785          11.9%  1,525,000
# 2                 383,482          -2.8%    161,000
# ...

# %%
df.set_index('Name', inplace = True)

df
# Out:
#                       Rank                    Industry Revenue (USD millions)  \
# Name
# Walmart                  1                      Retail                648,125
# Amazon                   2  Retail and cloud computing                574,785
# Apple                    3        Electronics industry                383,482
# UnitedHealth Group       4                  Healthcare                371,622
# Berkshire Hathaway       5                Conglomerate                364,482
# ...                    ...                         ...                    ...
# TIAA                    96                  Financials                 45,735
# CHS                     97     Agriculture cooperative                 45,590
# Bristol-Myers Squibb    98     Pharmaceutical industry                 45,006
# Dow Chemical Company    99           Chemical industry                 44,622
# Best Buy               100                      Retail                 43,452
#
# ...

# %%
df.loc['Apple']
# Out:
# Rank                                          3
# Industry                   Electronics industry
# Revenue (USD millions)                  383,482
# Revenue growth                            -2.8%
# Employees                               161,000
# Headquarters              Cupertino, California
# Name: Apple, dtype: object

# %%
df.iloc[2]
# Out:
# Rank                                          3
# Industry                   Electronics industry
# Revenue (USD millions)                  383,482
# Revenue growth                            -2.8%
# Employees                               161,000
# Headquarters              Cupertino, California
# Name: Apple, dtype: object

# %%
df.reset_index(inplace = True)

df
# Out:
#                     Name  Rank                    Industry  \
# 0                Walmart     1                      Retail
# 1                 Amazon     2  Retail and cloud computing
# 2                  Apple     3        Electronics industry
# 3     UnitedHealth Group     4                  Healthcare
# 4     Berkshire Hathaway     5                Conglomerate
# ..                   ...   ...                         ...
# 95                  TIAA    96                  Financials
# 96                   CHS    97     Agriculture cooperative
# 97  Bristol-Myers Squibb    98     Pharmaceutical industry
# 98  Dow Chemical Company    99           Chemical industry
# 99              Best Buy   100                      Retail
#
#    Revenue (USD millions) Revenue growth  Employees  \
# 0                 648,125           6.0%  2,100,000
# 1                 574,785          11.9%  1,525,000
# 2                 383,482          -2.8%    161,000
# ...

# %%
df.set_index(['Name', 'Industry'], inplace=True)

# %%
df
# Out:
#                                                  Rank Revenue (USD millions)  \
# Name                 Industry
# Walmart              Retail                         1                648,125
# Amazon               Retail and cloud computing     2                574,785
# Apple                Electronics industry           3                383,482
# UnitedHealth Group   Healthcare                     4                371,622
# Berkshire Hathaway   Conglomerate                   5                364,482
# ...                                               ...                    ...
# TIAA                 Financials                    96                 45,735
# CHS                  Agriculture cooperative       97                 45,590
# Bristol-Myers Squibb Pharmaceutical industry       98                 45,006
# Dow Chemical Company Chemical industry             99                 44,622
# Best Buy             Retail                       100                 43,452
#
# ...

# %%
pd.set_option('display.max.rows',101)

df
# Out:
#                                                                          Rank  \
# Name                                Industry
# Walmart                             Retail                                  1
# Amazon                              Retail and cloud computing              2
# Apple                               Electronics industry                    3
# UnitedHealth Group                  Healthcare                              4
# Berkshire Hathaway                  Conglomerate                            5
# CVS Health                          Healthcare                              6
# ExxonMobil                          Petroleum industry                      7
# Alphabet                            Technology and cloud computing          8
# McKesson Corporation                Health                                  9
# Cencora                             Pharmacy wholesale                     10
# ...
